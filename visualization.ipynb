# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ad_data = pd.read_csv('advertising (1).csv')

# %%
ad_data.head(20)
# Out:
#     Daily Time Spent on Site  Age  Area Income  Daily Internet Usage
# 0                      68.95   35     61833.90                256.09  \
# 1                      80.23   31     68441.85                193.77
# 2                      69.47   26     59785.94                236.50
# 3                      74.15   29     54806.18                245.89
# 4                      68.37   35     73889.99                225.58
# 5                      59.99   23     59761.56                226.74
# 6                      88.91   33     53852.85                208.36
# 7                      66.00   48     24593.33                131.76
# 8                      74.53   30     68862.00                221.51
# 9                      69.88   20     55642.32                183.82
# 10                     47.64   49     45632.51                122.02
# 11                     83.07   37     62491.01                230.87
# 12                     69.57   48     51636.92                113.12
# ...

# %%
newdf=ad_data.copy()

# %%
newdf.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage
# 0                     68.95   35     61833.90                256.09  \
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia  \
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
from datetime import datetime

# %%
newdf['date'] = pd.to_datetime(newdf['Timestamp'], format='%Y-%m-%d %H:%M:%S')

# %%
newdf['hour'] = newdf['date'].dt.hour
newdf['hour']
# Out:
# 0       0
# 1       1
# 2      20
# 3       2
# 4       3
#        ..
# 995    21
# 996     2
# 997    17
# 998     2
# 999    21
# Name: hour, Length: 1000, dtype: int32

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
newdf['Country']=le.fit_transform(newdf['Country'])
newdf['Ad Topic Line']=le.fit_transform(newdf['Ad Topic Line'])
newdf['City']=le.fit_transform(newdf['City'])

# %%
newdf.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage
# 0                     68.95   35     61833.90                256.09  \
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#    Ad Topic Line  City  Male  Country            Timestamp  Clicked on Ad
# 0             91   961     0      215  2016-03-27 00:53:11              0  \
# 1            464   903     1      147  2016-04-04 01:39:02              0
# 2            566   111     0      184  2016-03-13 20:35:42              0
# 3            903   939     1      103  2016-01-10 02:31:19              0
# 4            766   805     0       96  2016-06-03 03:36:18              0
#
#                  date  hour
# 0 2016-03-27 00:53:11     0
# 1 2016-04-04 01:39:02     1
# ...

# %%
newdf=newdf.drop(['date','Timestamp'],axis=1)

# %%
newdf.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage
# 0                     68.95   35     61833.90                256.09  \
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#    Ad Topic Line  City  Male  Country  Clicked on Ad  hour
# 0             91   961     0      215              0     0
# 1            464   903     1      147              0     1
# 2            566   111     0      184              0    20
# 3            903   939     1      103              0     2
# 4            766   805     0       96              0     3

# %%
Corr_Matrix = round(newdf.corr(),2)

print(Corr_Matrix)
# Out:
#                           Daily Time Spent on Site   Age  Area Income
# Daily Time Spent on Site                      1.00 -0.33         0.31  \
# Age                                          -0.33  1.00        -0.18
# Area Income                                   0.31 -0.18         1.00
# Daily Internet Usage                          0.52 -0.37         0.34
# Ad Topic Line                                -0.02 -0.02        -0.03
# City                                         -0.01 -0.01        -0.00
# Male                                         -0.02 -0.02         0.00
# Country                                      -0.01  0.00         0.05
# Clicked on Ad                                -0.75  0.49        -0.48
# hour                                          0.00 -0.05         0.03
#
#                           Daily Internet Usage  Ad Topic Line  City  Male
# Daily Time Spent on Site                  0.52          -0.02 -0.01 -0.02  \
# ...

# %%
sns.heatmap(Corr_Matrix)
# Out:
# <Axes: >
